# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train, y_train), (X_test,y_test) = datasets.cifar10.load_data()
X_train.shape
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 11s 0us/step
# (50000, 32, 32, 3)

# %%
X_test.shape
# Out:
# (10000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
y_train[:5]
# Out:
# <pre>array([[6],
#        [9],
#        [9],
#        [4],
#        [1]], dtype=uint8)</pre>

# %%
#converting 2d to 1d array
y_train = y_train.reshape(-1,)
y_train[:5]
# Out:
# <pre>array([6, 9, 9, 4, 1], dtype=uint8)</pre>

# %%
y_test = y_test.reshape(-1,)

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
#normalizing data
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
#building cnn
cnn = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)),
    layers.MaxPooling2D((2, 2)),
    
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
cnn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
cnn.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 5/10
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.7855 - accuracy: 0.7292
# Epoch 6/10
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7317 - accuracy: 0.7478
# Epoch 7/10
# 1563/1563 [==============================] - 171s 109ms/step - loss: 0.6780 - accuracy: 0.7651
# Epoch 8/10
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.6361 - accuracy: 0.7792
# Epoch 9/10
# 1563/1563 [==============================] - 219s 140ms/step - loss: 0.5972 - accuracy: 0.7937
# Epoch 10/10
# 1563/1563 [==============================] - 54s 35ms/step - loss: 0.5589 - accuracy: 0.8054

# %%
cnn.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 0.9241 - accuracy: 0.7007
# [0.9241132736206055, 0.7006999850273132]
